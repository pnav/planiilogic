# %% [markdown]
# # Assignment 1 - Due Class 4 (1/30/20)
#
# **Submission instructions:** Paul will share a Box upload link with you. Complete your answers to the questions below by double-clicking on each box and writing your answers. Use "Shift-Return" to store your new text in each answer box. Download the notebook, change the file name to your last name and UT EID, then upload the file to Box using the link. That's it!
#
#
# ## Objectives
# 1. Develop and explore notions of Strange Loops, provability vs. truth, and artificial vs. human intelligence.
# 2. Explore python variables, operators and logical expressions.

# %% [markdown]
# ## Student Info
#
# **Name:** *(your name here)*
#
# **UT EID:** *(your eid here)*

# %% [markdown]
# ## Question 1
# At the beginning of Class 3, you constructed a carefully designed exploratory instrument. How many dimensions does this object have?
#
# In a paragraph, defend your answer.

# %% [markdown]
# *(answer to Q1 here)*

# %% [markdown]
# ## Question 2
# In *GEB*, Hofstadter states that Godel's Incompletion Theorem "showed that provability is a weaker notion than truth". How does this observation impact your discipline and/or society at large? Expand your thoughts over several paragraphs.

# %% [markdown]
# *(answer to Q2 here)*

# %% [markdown]
# ## Question 3
# In *AI*, Mitchell asks "to what extent would human-level AI challenge how we thing about our own humanness?" In a few paragraphs, state what you would consider "human-level" AI and how its existence would (or does!) impact society at large or your area(s) of interest in particular.

# %% [markdown]
# *(answer to Q3 here)*

# %% [markdown]
# ## Code 1
# In the code cell below, using at least five different operators (where each parentheses set count as a single operator), and without reusing any number, write an expression that evaluates to `42`.
#
# *Brownie points for creativity!*

# %%
# code 1

# %% [markdown]
# ## Code 2
# In *GEB*, Hofstadter presented the **MU** puzzle. Write a conditional statement that checks whether a given string `s` is **MU**. Using the `print()` function, print a congratulatory message if so, and a consolatory message otherwise.
#
# *Brownie points for creativity!*

# %%
# code 2

# %% [markdown]
# ## Code 3
# In *GEB*, Hofstadter presented the *pq*-System. For given hyphen strings `x`, `y`, and `z` and a potential theorem string `t`, ***and using only the python we have covered so far***, write a conditional statement that checks whether `t` is a valid theorem derived using the *pq*-Sytem rule of inference. Using the `print()` function, print a congratulatory message if `t` is a valid theorem, and a consolatory message if not.
#
# Paste your solution into at least three code cells below demonstrating that it successfully discriminates valid and invalid theorems.
#
# *Don't get too creative ;-)*

# %%
# code 3.1

# %%
# code 3.2

# %%
# code 3.3

# %% [markdown]
# ## Question / Code Bonus
# In *GEB*, Hofstadter presented the *tq*-System. We haven't quite covered enough python yet to encode a Decision Procedure for it here, but in words, describe what additional python functionality you might need to perform such a procedure (i.e., using English, describe step by step how you would get the computer to check if a given string is a valid theorem in the *tq*-System). If you are feeling bold, do some web searches and try to code it!

# %%
# write your text (as a Markdown cell) and/or your code for the Bonus here
